# %%
import sys
import os
sys.path.insert(0, os.path.abspath("../"))
from analysis import *
import pandas as pd
from scipy import stats
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np
import random

# %%
settings_dict = {'': 'name'}

# %%
ana = Analysis('RQ2_f1', settings_dict)

# %%
get_aggregated_performance(ana.results, metric='test.f1_score')
# Out:
# config_settings       GP_     GSGP_  SLIM*SIG1_  SLIM*SIG2_  SLIM+SIG1_  \
# dataset_name
# blood            0.494478  0.492392    0.485791    0.485791    0.498532
# clima            0.953688  0.954210    0.954839    0.954839    0.951271
# eeg              0.641370  0.638739    0.621957    0.621957    0.628830
# fertility        0.085000  0.139048    0.246476    0.246476    0.160325
# gina             0.822124  0.752453    0.668573    0.668573    0.724036
# hill             0.713753  0.795979    0.666045    0.666045    0.716702
# ilpd             0.823960  0.829311    0.834448    0.834448    0.832029
# kc               0.441979  0.428461    0.406286    0.406286    0.433265
# liver            0.588574  0.588638    0.584377    0.584377    0.590676
# musk             0.672034  0.692447    0.645742    0.645742    0.658978
# ozone            0.191677  0.178163    0.130091    0.130091    0.178568
# pc1              0.227459  0.280868    0.212627    0.212627    0.254438
# pc3              0.379574  0.351927    0.309612    0.309612    0.335845
# qsar             0.736073  0.751709    0.589661    0.589661    0.674303
# retinopathy      0.751994  0.737079    0.706394    0.706394    0.715345
# scene            0.559679  0.618905    0.354435    0.354435    0.519036
# spam             0.871474  0.912080    0.716491    0.716491    0.873628
# spect            0.881328  0.886466    0.881983    0.881983    0.876504
#
# config_settings  SLIM+SIG2_
# dataset_name
# blood              0.502462
# clima              0.951975
# eeg                0.629416
# fertility          0.175714
# gina               0.744876
# hill               0.705048
# ilpd               0.831362
# kc                 0.433869
# liver              0.596641
# musk               0.665183
# ozone              0.133890
# pc1                0.281127
# pc3                0.330328
# qsar               0.694110
# retinopathy        0.719769
# scene              0.566370
# spam               0.876075
# spect              0.887026

# %%
get_aggregated_performance(ana.results, metric='nodes_count')
# Out:
# config_settings    GP_   GSGP_  SLIM*SIG1_  SLIM*SIG2_  SLIM+SIG1_  SLIM+SIG2_
# dataset_name
# blood            514.0   975.0        13.0        13.0        90.4        93.7
# clima            101.4  1706.0         3.0         3.0        88.4        94.9
# eeg              163.2   969.6        24.6        24.6        84.1        93.4
# fertility        231.6  1294.4        20.2        20.2       119.5       121.8
# gina              94.6  1503.4         4.2         4.2       115.4       122.7
# hill             138.2  1951.8        10.2        10.2       121.3       112.8
# ilpd             324.2  1003.6         7.4         7.4        58.5        73.2
# kc               181.6  1362.4        16.4        16.4       108.2       118.5
# liver            523.4  1169.0         9.8         9.8        83.9        91.9
# musk             135.6  1640.4         3.8         3.8        79.3        70.0
# ozone            220.2  1564.8        20.0        20.0       114.0       116.5
# pc1              141.4  1478.0         6.2         6.2       111.7       125.9
# pc3              191.2  1668.0        12.2        12.2       115.0       128.3
# qsar             261.4  1757.0        13.0        13.0       114.0       130.8
# retinopathy      145.4  1571.6         9.8         9.8       106.9       115.5
# scene            115.0  1906.8        11.4        11.4       116.3       126.6
# spam             221.8  1567.6         8.6         8.6       113.5       127.0
# spect             86.4  1441.0         3.4         3.4        92.6       108.3

# %%
get_performance_difference_significance_table(ana.results.loc[(ana.results['name'] != 'SLIM+SIG1') & (ana.results['name'] != 'SLIM*SIG1')]
                                              , config='SLIM*SIG2_', metric='test.f1_score', pivot = True)
# Out:
# c:\Users\leond\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# c:\Users\leond\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# config1_v_config2 SLIM*SIG2__VS_GP_ SLIM*SIG2__VS_GSGP_  \
# dataset_name
# blood                     0.846 (≈)           0.594 (≈)
# clima                     0.655 (≈)           0.514 (≈)
# eeg                       0.002 (-)           0.018 (-)
# fertility                 0.038 (+)           0.193 (≈)
# gina                      0.002 (-)           0.002 (-)
# hill                      0.027 (-)           0.002 (-)
# ilpd                      0.004 (+)           0.128 (≈)
# kc                        0.006 (-)           0.004 (-)
# liver                     0.432 (≈)           0.492 (≈)
# musk                      0.064 (≈)           0.028 (-)
# ozone                     0.037 (-)           0.260 (≈)
# pc1                       0.695 (≈)           0.084 (≈)
# pc3                       0.002 (-)           0.006 (-)
# qsar                      0.002 (-)           0.002 (-)
# retinopathy               0.002 (-)           0.002 (-)
# scene                     0.002 (-)           0.002 (-)
# spam                      0.002 (-)           0.002 (-)
# spect                     0.893 (≈)           0.695 (≈)
#
# config1_v_config2 SLIM*SIG2__VS_SLIM+SIG2_
# dataset_name
# blood                            0.575 (≈)
# clima                            0.050 (≈)
# eeg                              0.043 (-)
# fertility                        0.260 (≈)
# gina                             0.002 (-)
# hill                             0.002 (-)
# ilpd                             0.273 (≈)
# kc                               0.008 (-)
# liver                            0.025 (-)
# musk                             0.144 (≈)
# ozone                            0.889 (≈)
# pc1                              0.004 (-)
# pc3                              0.037 (-)
# qsar                             0.002 (-)
# retinopathy                      0.011 (-)
# scene                            0.002 (-)
# spam                             0.002 (-)
# spect                            0.441 (≈)

# %%
get_performance_difference_significance_table(ana.results.loc[(ana.results['name'] != 'SLIM*SIG1') & (ana.results['name'] != 'SLIM*SIG2')], 
                                              config='SLIM+SIG1_', metric='test.f1_score', pivot='True')
# Out:
# c:\Users\leond\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# c:\Users\leond\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# config1_v_config2 SLIM+SIG1__VS_GP_ SLIM+SIG1__VS_GSGP_  \
# dataset_name
# blood                     1.000 (≈)           0.889 (≈)
# clima                     0.123 (≈)           0.322 (≈)
# eeg                       0.064 (≈)           0.018 (-)
# fertility                 0.279 (≈)           0.833 (≈)
# gina                      0.004 (-)           0.492 (≈)
# hill                      0.846 (≈)           0.006 (-)
# ilpd                      0.010 (+)           0.398 (≈)
# kc                        0.432 (≈)           0.557 (≈)
# liver                     0.770 (≈)           0.678 (≈)
# musk                      0.193 (≈)           0.050 (-)
# ozone                     0.374 (≈)           0.859 (≈)
# pc1                       0.625 (≈)           0.322 (≈)
# pc3                       0.020 (-)           0.086 (≈)
# qsar                      0.037 (-)           0.002 (-)
# retinopathy               0.010 (-)           0.008 (-)
# scene                     0.322 (≈)           0.037 (-)
# spam                      0.695 (≈)           0.002 (-)
# spect                     0.695 (≈)           0.515 (≈)
#
# config1_v_config2 SLIM+SIG1__VS_SLIM+SIG2_
# dataset_name
# blood                            0.889 (≈)
# clima                            0.953 (≈)
# eeg                              0.500 (≈)
# fertility                        0.715 (≈)
# gina                             0.105 (≈)
# hill                             0.625 (≈)
# ilpd                             0.893 (≈)
# kc                               0.767 (≈)
# liver                            0.398 (≈)
# musk                             0.866 (≈)
# ozone                            0.038 (+)
# pc1                              0.049 (-)
# pc3                              0.432 (≈)
# qsar                             0.232 (≈)
# retinopathy                      0.314 (≈)
# scene                            0.557 (≈)
# spam                             0.770 (≈)
# spect                            0.084 (≈)

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Unique datasets
unique_datasets = ana.logs['dataset'].unique()

# Create subplots
fig, ax = plt.subplots(len(unique_datasets), 2, figsize=(12, 30), squeeze=False)

for i, dataset in enumerate(unique_datasets):
    dataset_logs = ana.logs[ana.logs['dataset'] == dataset]

    # Call the function without assignment
    plot_value_by_generations(dataset_logs, 'elite_train_error', ax=ax[i, 0])
    plot_value_by_generations(dataset_logs, 'elite_test_error', ax=ax[i, 1])

fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(int(len(unique_datasets)/2), 2, figsize=(12, 15), squeeze=False)

j = 0
i = 0
for dataset in unique_datasets:
    dataset_logs = ana.logs[ana.logs['dataset'] == dataset]
    plot_value_by_generations(dataset_logs, 'elite_nodes', ax=ax[i, j], y_max=500)
    j = (j + 1) % 2
    i = i +1 if j == 0 else i

fig.tight_layout()
plt.show()

# %%
2 % 2
# Out:
# 0

# %%
ana.logs['dataset'].unique()
# Out:
# array(['blood', 'clima', 'eeg', 'fertility', 'gina', 'hill', 'ilpd', 'kc',
#        'liver', 'musk', 'ozone', 'pc1', 'pc3', 'qsar', 'retinopathy',
#        'scene', 'spam', 'spect'], dtype=object)

# %%
ax
# Out:
# array([[<Axes: title={'center': 'blood'}, xlabel='Generation', ylabel='elite_nodes'>,
#         <Axes: title={'center': 'clima'}, xlabel='Generation', ylabel='elite_nodes'>],
#        [<Axes: title={'center': 'eeg'}, xlabel='Generation', ylabel='elite_nodes'>,
#         <Axes: title={'center': 'fertility'}, xlabel='Generation', ylabel='elite_nodes'>],
#        [<Axes: title={'center': 'gina'}, xlabel='Generation', ylabel='elite_nodes'>,
#         <Axes: title={'center': 'hill'}, xlabel='Generation', ylabel='elite_nodes'>],
#        [<Axes: title={'center': 'ilpd'}, xlabel='Generation', ylabel='elite_nodes'>,
#         <Axes: title={'center': 'kc'}, xlabel='Generation', ylabel='elite_nodes'>],
#        [<Axes: title={'center': 'liver'}, xlabel='Generation', ylabel='elite_nodes'>,
#         <Axes: title={'center': 'musk'}, xlabel='Generation', ylabel='elite_nodes'>],
#        [<Axes: title={'center': 'ozone'}, xlabel='Generation', ylabel='elite_nodes'>,
#         <Axes: title={'center': 'pc1'}, xlabel='Generation', ylabel='elite_nodes'>],
#        [<Axes: title={'center': 'pc3'}, xlabel='Generation', ylabel='elite_nodes'>,
#         <Axes: title={'center': 'qsar'}, xlabel='Generation', ylabel='elite_nodes'>],
#        [<Axes: title={'center': 'retinopathy'}, xlabel='Generation', ylabel='elite_nodes'>,
#         <Axes: title={'center': 'scene'}, xlabel='Generation', ylabel='elite_nodes'>],
#        [<Axes: title={'center': 'spam'}, xlabel='Generation', ylabel='elite_nodes'>,
#         <Axes: title={'center': 'spect'}, xlabel='Generation', ylabel='elite_nodes'>]],
#       dtype=object)
