# %%
import sys
import os
sys.path.insert(0, os.path.abspath("../"))
from analysis import *
import pandas as pd
from scipy import stats
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np
import random

# %%
settings_dict = {'': 'name'}

# %%
ana = Analysis('RQ2', settings_dict)

# %%
get_aggregated_performance(ana.results, metric='test.rmse', agg='mean')
# Out:
# config_settings       GP_     GSGP_  SLIM*SIG1_  SLIM*SIG2_  SLIM+SIG1_  \
# dataset_name
# blood            0.401306  0.389545    0.403087    0.401561    0.400085
# clima            0.215679  0.197931    0.237601    0.244721    0.238708
# eeg              0.486225  0.467960    0.487511    0.490304    0.477996
# fertility        0.404587  0.385719    0.355607    0.355395    0.359350
# gina             0.444701  0.336253    0.484904    0.490836    0.371435
# hill             0.420742  0.340985    0.491307    0.489224    0.429965
# ilpd             0.422296  0.423220    0.421152    0.423255    0.422190
# kc               0.335124  0.330234    0.336025    0.336616    0.341220
# liver            0.467776  0.457445    0.489472    0.483803    0.455841
# musk             0.491002  0.362285    0.486487    0.479097    0.426965
# ozone            0.166824  0.166787    0.161388    0.161373    0.162742
# pc1              0.247223  0.249913    0.242495    0.240050    0.247753
# ...

# %%
get_aggregated_performance(ana.results, metric='nodes_count')
# Out:
# config_settings    GP_   GSGP_  SLIM*SIG1_  SLIM*SIG2_  SLIM+SIG1_  SLIM+SIG2_
# dataset_name
# blood            405.4  2224.6       125.7       138.6       121.4       133.4
# clima            250.8  2586.2       120.1       134.6       114.4       127.4
# eeg              321.6  2362.2       118.5       134.0       114.9       135.7
# fertility        340.8  2638.4       129.6       141.3       119.5       126.3
# gina             212.0  2269.6       109.3       119.3       114.0       124.4
# hill             160.0  2504.8       124.0       137.7       127.7       136.2
# ilpd             596.6  2297.2       123.4       133.7       111.7       125.5
# kc               288.0  2184.8       118.4       134.8       115.0       124.4
# liver            596.2  2448.2       132.4       143.4       123.2       139.1
# musk             159.2  2144.8       114.9       138.9       122.7       133.2
# ozone            156.8  2469.8       121.8       134.2       113.9       126.1
# ...

# %%
get_performance_difference_significance_table(ana.results.loc[(ana.results['name'] != 'SLIM*SIG1') & (ana.results['name'] != 'SLIM+SIG2')]
                                              , config='SLIM+SIG1_', metric='test.rmse', pivot = True)
# Out:
# c:\Users\leond\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# c:\Users\leond\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# config1_v_config2 SLIM+SIG1__VS_GP_ SLIM+SIG1__VS_GSGP_  \
# dataset_name
# blood                     0.432 (≈)           0.010 (-)
# clima                     0.010 (-)           0.002 (-)
# eeg                       0.004 (+)           0.002 (-)
# fertility                 0.193 (≈)           0.160 (≈)
# gina                      0.002 (+)           0.002 (-)
# hill                      0.492 (≈)           0.002 (-)
# ...

# %%
get_performance_difference_significance_table(ana.results.loc[(ana.results['name'] != 'SLIM*SIG1') & (ana.results['name'] != 'SLIM*SIG2')], 
                                              config='SLIM+SIG1_', metric='test.f1_score', pivot='True')
# Out:
# c:\Users\leond\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_morestats.py:4088: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# c:\Users\leond\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\stats\_morestats.py:4102: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")
# config1_v_config2 SLIM+SIG1__VS_GP_ SLIM+SIG1__VS_GSGP_  \
# dataset_name
# blood                     0.027 (+)           0.020 (-)
# clima                     0.374 (≈)           0.002 (-)
# eeg                       0.131 (≈)           0.037 (-)
# fertility                 0.285 (≈)           0.017 (-)
# gina                      0.002 (+)           0.002 (-)
# hill                      0.922 (≈)           0.002 (-)
# ...

# %%
get_aggregated_performance(ana.results, metric='test.f1_score')
# Out:
# config_settings       GP_     GSGP_  SLIM*SIG1_  SLIM*SIG2_  SLIM+SIG1_  \
# dataset_name
# blood            0.143382  0.458985    0.000000    0.000000    0.336948
# clima            0.959859  0.971621    0.954839    0.954839    0.956672
# eeg              0.341494  0.562544    0.061957    0.062056    0.486495
# fertility        0.076364  0.239365    0.000000    0.000000    0.028571
# gina             0.694843  0.850163    0.161970    0.125332    0.808477
# hill             0.739853  0.856321    0.512741    0.532798    0.745716
# ilpd             0.833598  0.811609    0.833502    0.819734    0.823339
# kc               0.111365  0.332164    0.000000    0.014414    0.216329
# liver            0.544781  0.626270    0.008889    0.044183    0.596396
# musk             0.456452  0.794507    0.417879    0.313094    0.670665
# ozone            0.030556  0.190124    0.000000    0.000000    0.017029
# pc1              0.113861  0.170793    0.000000    0.000000    0.078487
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Unique datasets
unique_datasets = ana.logs['dataset'].unique()

# Create subplots
fig, ax = plt.subplots(len(unique_datasets), 2, figsize=(10, 30), squeeze=False)

for i, dataset in enumerate(unique_datasets):
    dataset_logs = ana.logs[ana.logs['dataset'] == dataset]

    # Call the function without assignment
    plot_value_by_generations(dataset_logs, 'elite_train_error', ax=ax[i, 0])
    plot_value_by_generations(dataset_logs, 'elite_test_error', ax=ax[i, 1])

fig.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(int(len(unique_datasets)/2), 2, figsize=(10, 15), squeeze=False)

j = 0
i = 0
for dataset in unique_datasets:
    dataset_logs = ana.logs[ana.logs['dataset'] == dataset]
    plot_value_by_generations(dataset_logs, 'elite_nodes', ax=ax[i, j], y_max=200)
    j = (j + 1) % 2
    i = i +1 if j == 0 else i

fig.tight_layout()
plt.show()

# %%
get_avg_ranking(ana.results, metric='test.rmse')
# Out:
#   config_settings  avg_rank
# 0           GSGP_  2.500000
# 1      SLIM+SIG1_  3.222222
# 2      SLIM+SIG2_  3.222222
# 3             GP_  3.722222
# 4      SLIM*SIG1_  4.000000
# 5      SLIM*SIG2_  4.333333

# %%
get
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 get
#
# NameError: name 'get' is not defined

# %%
get_rankings(ana.results, metric='test.rmse')
# Out:
# config_settings  GP_  GSGP_  SLIM*SIG1_  SLIM*SIG2_  SLIM+SIG1_  SLIM+SIG2_
# dataset_name
# blood            4.0    1.0         6.0         5.0         3.0         2.0
# clima            2.0    1.0         3.0         5.0         4.0         6.0
# eeg              4.0    1.0         5.0         6.0         3.0         2.0
# fertility        6.0    5.0         3.0         2.0         4.0         1.0
# gina             4.0    1.0         5.0         6.0         2.0         3.0
# hill             2.0    1.0         6.0         5.0         3.0         4.0
# ilpd             4.0    5.0         1.0         6.0         3.0         2.0
# kc               2.0    1.0         3.0         4.0         6.0         5.0
# liver            4.0    3.0         6.0         5.0         2.0         1.0
# musk             6.0    1.0         5.0         4.0         3.0         2.0
# ozone            6.0    5.0         2.0         1.0         3.0         4.0
# ...

# %%
get_ranking_significance(get_rankings(ana.results, metric='test.rmse'))
# Out:
# 0.050443969853697763
