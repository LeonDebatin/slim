# %%
import pandas as pd

# %%
df = pd.read_csv('log/gsgp_f1.csv', header=None)
df.columns = ['alogrithm', 'id', 'dataset', 'seed', 'generation', 'elite_train_error', 'time', 'population_nodes', 'elite_test_error', 'elite_nodes', 'log_level']
df
# Out:
#         alogrithm                                    id    dataset  seed  \
# 0    StandardGSGP  b13700c8-0012-11f0-8457-089df4bf3532  dataset_1     0
# 1    StandardGSGP  b13700c8-0012-11f0-8457-089df4bf3532  dataset_1     0
# 2    StandardGSGP  b13700c8-0012-11f0-8457-089df4bf3532  dataset_1     0
# 3    StandardGSGP  b13700c8-0012-11f0-8457-089df4bf3532  dataset_1     0
# 4    StandardGSGP  b13700c8-0012-11f0-8457-089df4bf3532  dataset_1     0
# ..            ...                                   ...        ...   ...
# 496  StandardGSGP  b13700c8-0012-11f0-8457-089df4bf3532  dataset_1     0
# 497  StandardGSGP  b13700c8-0012-11f0-8457-089df4bf3532  dataset_1     0
# 498  StandardGSGP  b13700c8-0012-11f0-8457-089df4bf3532  dataset_1     0
# 499  StandardGSGP  b13700c8-0012-11f0-8457-089df4bf3532  dataset_1     0
# 500  StandardGSGP  b13700c8-0012-11f0-8457-089df4bf3532  dataset_1     0
#
#      generation  elite_train_error      time  population_nodes  \
# ...
