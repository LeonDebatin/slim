# %%
import pandas as pd

# %%
df = pd.read_csv('log/gsgp_f1.csv', header=None)
df.columns = ['alogrithm', 'id', 'dataset', 'kp', 'generation', 'train_error', 'time', 'kp2', 'test_error', 'nodes', 'kp3']
df
# Out:
#                0                                     1          2   3    4   \
# 0    StandardGSGP  b13700c8-0012-11f0-8457-089df4bf3532  dataset_1   0    0
# 1    StandardGSGP  b13700c8-0012-11f0-8457-089df4bf3532  dataset_1   0    1
# 2    StandardGSGP  b13700c8-0012-11f0-8457-089df4bf3532  dataset_1   0    2
# 3    StandardGSGP  b13700c8-0012-11f0-8457-089df4bf3532  dataset_1   0    3
# 4    StandardGSGP  b13700c8-0012-11f0-8457-089df4bf3532  dataset_1   0    4
# ..            ...                                   ...        ...  ..  ...
# 496  StandardGSGP  b13700c8-0012-11f0-8457-089df4bf3532  dataset_1   0  496
# 497  StandardGSGP  b13700c8-0012-11f0-8457-089df4bf3532  dataset_1   0  497
# 498  StandardGSGP  b13700c8-0012-11f0-8457-089df4bf3532  dataset_1   0  498
# 499  StandardGSGP  b13700c8-0012-11f0-8457-089df4bf3532  dataset_1   0  499
# 500  StandardGSGP  b13700c8-0012-11f0-8457-089df4bf3532  dataset_1   0  500
#
#            5         6          7         8     9   10
# ...
