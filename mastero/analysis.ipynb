# %%
import pandas as pd

# %%
df_analytics = pd.read_csv('log/gsgp.csv')
df_analytics.columns = ['alogrithm', 'id', 'dataset', 'seed', 'generation', 'elite_train_error', 'time', 'population_nodes', 'elite_test_error', 'elite_nodes', 'log_level']
df_analytics
# Out:
#          alogrithm                                    id dataset  seed  \
# 0     StandardGSGP  b1c40480-0117-11f0-adf2-089df4bf3532   blood    74
# 1     StandardGSGP  b1c40480-0117-11f0-adf2-089df4bf3532   blood    74
# 2     StandardGSGP  b1c40480-0117-11f0-adf2-089df4bf3532   blood    74
# 3     StandardGSGP  b1c40480-0117-11f0-adf2-089df4bf3532   blood    74
# 4     StandardGSGP  b1c40480-0117-11f0-adf2-089df4bf3532   blood    74
# ...            ...                                   ...     ...   ...
# 3024  StandardGSGP  0647b03e-0118-11f0-8326-089df4bf3532   blood    74
# 3025  StandardGSGP  0647b03e-0118-11f0-8326-089df4bf3532   blood    74
# 3026  StandardGSGP  0647b03e-0118-11f0-8326-089df4bf3532   blood    74
# 3027  StandardGSGP  0647b03e-0118-11f0-8326-089df4bf3532   blood    74
# 3028  StandardGSGP  0647b03e-0118-11f0-8326-089df4bf3532   blood    74
#
#       generation  elite_train_error      time  population_nodes  \
# ...
